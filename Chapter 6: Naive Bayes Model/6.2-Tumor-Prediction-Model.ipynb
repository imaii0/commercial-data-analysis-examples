# %% [markdown]
# # 第六章 朴素贝叶斯模型

# %%
X = df.drop(columns='肿瘤性质') 
y = df['肿瘤性质']   分析与机器学习商业案例实战\第6章 朴素贝叶斯模型\源代码汇总_Jupyter Notebook格式（推荐）\肿瘤数据.xlsx")
df.head(100)
# Out:
#       最大周长    最大凹陷度     平均凹陷度    最大面积   最大半径  平均灰度值  肿瘤性质
# 0   184.60  0.26540  0.147100  2019.0  25.38  17.33     0
# 1   158.80  0.18600  0.070170  1956.0  24.99  23.41     0
# 2   152.50  0.24300  0.127900  1709.0  23.57  25.53     1
# 3    98.87  0.25750  0.105200   567.7  14.91  26.50     0
# 4   152.20  0.16250  0.104300  1575.0  22.54  16.67     0
# ..     ...      ...       ...     ...    ...    ...   ...
# 95  156.10  0.15730  0.086830  1750.0  24.22  31.59     0
# 96   82.14  0.05882  0.029410   495.2  12.83  20.92     1
# 97   68.81  0.02381  0.007937   366.1  10.92  26.29     1
# 98   82.96  0.08449  0.033500   512.5  13.06  17.16     1
# 99  109.50  0.15650  0.058390   826.4  16.33  30.86     0
#
# [100 rows x 7 columns]

# %%
X = df.drop(columns='肿瘤性质') 
y = df['肿瘤性质']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

# %% [markdown]
# ## 逻辑回归模型

# %%
#模型训练及搭建
from sklearn.linear_model import LogisticRegression
lr_clf = LogisticRegression(random_state=1, max_iter=1000) 
lr_clf.fit(X_train, y_train)
LogisticRegression(max_iter=1000, random_state=1)
# Out:
# LogisticRegression(max_iter=1000, random_state=1)

# %%
#模型预测及评估
y_pred_lr = lr_clf.predict(X_test)
y_pred_lr[:100]

b = pd.DataFrame()
b['预测值'] = list(y_pred_lr)
b['实际值'] = list(y_test)
b.head()

from sklearn.metrics import accuracy_score
score_lr = accuracy_score(y_pred_lr, y_test)
score_lr
# Out:
# 0.9298245614035088

# %% [markdown]
# ## 随机森林模型

# %%
#模型训练及搭建
from sklearn.ensemble import RandomForestClassifier
rf_clf = RandomForestClassifier(random_state=1)
rf_clf.fit(X_train, y_train)
RandomForestClassifier(random_state=1)
# Out:
# RandomForestClassifier(random_state=1)

# %%
#模型预测及评估
y_pred_rf = rf_clf.predict(X_test)
y_pred_rf[:100]

c = pd.DataFrame()
c['预测值'] = list(y_pred_rf)
c['实际值'] = list(y_test)
c.head()

from sklearn.metrics import accuracy_score
score_rf = accuracy_score(y_pred_rf, y_test)
score_rf
# Out:
# 0.956140350877193

# %% [markdown]
# ## 支持向量机模型

# %%
#模型训练及搭建
from sklearn.svm import SVC
svm_clf = SVC(random_state=1)
svm_clf.fit(X_train, y_train)
SVC(random_state=1)
# Out:
# SVC(random_state=1)

# %%
#模型预测及评估
y_pred_svm = svm_clf.predict(X_test)
y_pred_svm[:100]

d = pd.DataFrame()
d['预测值'] = list(y_pred_svm)
d['实际值'] = list(y_test)
d.head()

from sklearn.metrics import accuracy_score
score_svm = accuracy_score(y_pred_svm, y_test)
score_svm
# Out:
# 0.9035087719298246
